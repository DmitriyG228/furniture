# %%
# default_exp learn

# %%
#export 
import pandas as pd
from pymongo import MongoClient
from pathlib import Path
import shutil
from mytools.tools import *
from fur.paths import *
from annoy import AnnoyIndex

from fastai.vision.all import *

import nested_lookup

# %%
#export
def save_file_from_url(url, fname):
    r = requests.get(url, allow_redirects=True)
    open(fname, 'wb').write(r.content)

# %%
def images_df():
    pics_path = ssd_pictures_path
#     pics_path = Path('/home/dima/houzz_parse/PICS')
    mongo_connect = MongoClient('mongodb://localhost:27017')
    mongodb = mongo_connect['houzz']
    cursor =mongodb['FurnitureItem'].find()
    data = list(cursor)
    pics = pd.DataFrame(list(pics_path.ls()),columns=['paths'])
    pics['file_name'] = pics['paths'].apply(lambda x:x.name)
    pics['image'] = pics['file_name'].str.split('_').str[0]
    data_filtered = nested_lookup.nested_delete(data,'url_img_product')
    img_keys = nested_lookup.nested_lookup('url_img_product',data)
    img_keys = [list(item.keys()) for item in img_keys]
    df = pd.json_normalize(data_filtered)
    df.columns = [c.split('.')[1] if len(c.split('.'))>1 else c for c in df.columns ]
    df['image'] = img_keys
    df = df.explode('image')
    df = pics.merge(df,on='image')
    df = df.drop_duplicates('image').reset_index(drop=True)
    df.columns = df.columns.str.lower()
    return df.drop(columns=['file_name','image','_id'])

# %%
#export
def mk_model_dir(learner_name):
    model_name = f'model_{learner_name}_{pd.Timestamp.now()}'
    model_path = models_path/model_name
    if not model_path.is_dir(): model_path.mkdir()
    return model_path

# %%
mapping_df = images_df()
mapping_df = mapping_df[mapping_df['category']=='Sofas'].reset_index(drop=True)
mapping_df = mapping_df[['paths','color','materials','style']]

# %%
mapping_df['color'] = mapping_df['color'].str.lower()
mapping_df['color'] = mapping_df['color'].str.split(' ')
mapping_df = mapping_df.explode('color')
mapping_df['color'] = mapping_df['color'].str.split('/')
mapping_df = mapping_df.explode('color')
color = mapping_df.groupby(['color'])['paths'].count().sort_values(ascending=False)[:50].index
color = color.drop('light','finish:')
mapping_df.loc[~mapping_df['color'].isin(color),'color'] = np.nan
mapping_df = mapping_df.reset_index().sort_values('color',ascending=False).drop_duplicates('index').reset_index(drop=True)

# %%
len(mapping_df)
# Out:
# 25588

# %%
pdrows(10)

# %%
mapping_df['materials'] = mapping_df['materials'].str.lower()
mapping_df['materials'] = mapping_df['materials'].str.split(' ')
mapping_df = mapping_df.explode('materials')
mapping_df['materials'] = mapping_df['materials'].str.split('/')
mapping_df = mapping_df.explode('materials')
mapping_df['materials'] = mapping_df['materials'].str.split('&')
mapping_df = mapping_df.explode('materials')
mapping_df['materials'] = mapping_df['materials'].str.split(',')
mapping_df = mapping_df.explode('materials')

# %%
materials = mapping_df.groupby(['materials'])['paths'].count().sort_values(ascending=False)[:50].index

# %%
materials = materials.drop(['100%','and','','wood','manufactured','hypoallergenic','stainless','electroplated','vegan','dried'])

# %%
materials
# Out:
# Index(['solid', 'velvet', 'fabric', 'foam', 'frame', 'fabrics', 'hardwood',
#        'leather', 'cushioning', 'engineered', 'ash', 'weave', 'steel',
#        'rattan', 'upholstery', 'polyester', 'birch', 'mod', 'plywood',
#        'oxford', 'linen', 'peel', 'metal', 'pebble', 'suede', 'micro',
#        'frames', 'wicker', 'grain', 'cross', 'rubber', 'top', 'iron', 'kiln',
#        'satin', 'density', 'faux', 'rubberwood', 'spring', 'm3'],
#       dtype='object', name='materials')

# %%
mapping_df.loc[~mapping_df['materials'].isin(color),'materials'] = np.nan
mapping_df = mapping_df.reset_index().sort_values('materials',ascending=False).drop_duplicates('index').reset_index(drop=True)

# %%
len(mapping_df)
# Out:
# 25588

# %%
mapping_df['labels'] = mapping_df['color']+','+mapping_df['style']+','+mapping_df['materials']

# %%
mapping_df = mapping_df[['paths','labels']]

# %%
mapping_df['paths'] = mapping_df['paths'].apply(lambda x:x.name)
# Out:
# <ipython-input-135-eab2fdd4bf80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapping_df['paths'] = mapping_df['paths'].apply(lambda x:x.name)

# %%
mapping_df = mapping_df.dropna()

# %%
mapping_df.loc[mapping_df.sample(int(len(mapping_df)/5)).index,'is_valid'] = True

# %%
mapping_df['is_valid'] = mapping_df['is_valid'].fillna(False)

# %%
len(mapping_df)
# Out:
# 6823

# %%
drop_labels = set(mapping_df[mapping_df['is_valid']==True]['labels'])^set(mapping_df[mapping_df['is_valid']==False]['labels'])

# %%
mapping_df = mapping_df[~mapping_df['labels'].isin(drop_labels)]

# %%
len(mapping_df['labels'].unique())
# Out:
# 144

# %%
dls = ImageDataLoaders.from_df(mapping_df, path = ssd_pictures_path, 
                               label_col=1, item_tfms=Resize(224), valid_col='is_valid', 
                               metrics=partial(accuracy_multi, thresh=0.5),label_delim=',')

# %%
dls.show_batch()

# %% [markdown]
# #### learn

# %%
learn = cnn_learner(dls,resnet34, metrics=partial(accuracy_multi, thresh=0.5))

# %%
learn.fine_tune(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.812268</td>
#       <td>0.394266</td>
#       <td>0.893336</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.304775</td>
#       <td>0.125264</td>
#       <td>0.971860</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.160746</td>
#       <td>0.093134</td>
#       <td>0.973805</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### extra train

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=1.318256749982538e-07, lr_steep=2.2908675418875646e-06)

# %%
learn.fit_one_cycle(2, slice(2e-6, 1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.978554</td>
#       <td>1.070119</td>
#       <td>0.282932</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.951821</td>
#       <td>1.059802</td>
#       <td>0.279416</td>
#       <td>00:47</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### interpret

# %%
learn.show_results()

# %%
interp = Interpretation.from_learner(learn)
interp.plot_top_losses(9)

# %% [markdown]
# #### load

# %%
list(models_path.ls())
# Out:
# [Path('/home/dima/furniture_data/models/sofas_styles_10_11_multi'),
#  Path('/home/dima/furniture_data/models/model_sofas_style_color_2020-11-11 09:56:56.142558'),
#  Path('/home/dima/furniture_data/models/sofas_styles_7_11'),
#  Path('/home/dima/furniture_data/models/model_sofas_style_color_2020-11-11 09:43:08.330496'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_1_2020-11-11 15:48:33.725229'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_2020-11-11 14:41:20.183324'),
#  Path('/home/dima/furniture_data/models/sofas_styles_10_11_color'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_1_2020-11-11 15:17:33.805257'),
#  Path('/home/dima/furniture_data/models/.ipynb_checkpoints'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_1_2020-11-11 15:55:30.330790'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_10_11_2020-11-11 10:30:29.869152'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles_10_11_color_2020-11-11 09:03:24.433698'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_2_2020-11-11 16:03:35.287205'),
#  Path('/home/dima/furniture_data/models/sofas_styles_10_11_91pc'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_1_2020-11-11 15:40:27.013284'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_2_2020-11-11 16:06:59.246045'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_1_2020-11-11 15:46:34.200347'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_10_11_2020-11-11 10:31:22.893645'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_stable'),
#  Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_1_2020-11-11 15:39:24.617549')]

# %%
models_path/path_info(models_path).sort_values(['time'])['name'].iloc[-1]
# Out:
# Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_11_11_2_2020-11-11 16:06:59.246045')

# %%
learn = load_learner(models_path/path_info(models_path).sort_values(['time'])['name'].iloc[-1]/'model.pkl')

# %%
learn.dls = dls

# %% [markdown]
# #### save model

# %%
model_path = mk_model_dir('sofas_styles__color_singlelabel_11_11_2')

# %%
learn.export(model_path/'model.pkl')

# %% [markdown]
# ### annoy

# %%
# export 
# this is a hook (learned about it here: https://forums.fast.ai/t/how-to-find-similar-images-based-on-final-embedding-layer/16903/13)
# hooks are used for saving intermediate computations
class SaveFeatures():
    features=None
    def __init__(self, m): 
        self.hook = m.register_forward_hook(self.hook_fn)
        self.features = None
    def hook_fn(self, module, input, output): 
        out = output.detach().cpu().numpy()
        if isinstance(self.features, type(None)):
            self.features = out
        else:
            self.features = np.row_stack((self.features, out))
    def remove(self): 
        self.hook.remove()

# %%
sf = SaveFeatures(learn.model[1][7]) ## Output before the last FC layer

# %%
_= learn.get_preds(ds_idx=0)
# _= learn.get_preds(ds_idx=1)

# %%
# _= learn.get_preds(ds_idx=1)

# %%
len(sf.features)
# Out:
# 14697

# %%
img_path = [str(x) for x in list(dls.train_ds.items['paths'])];len(img_path)
# Out:
# 14697

# %%
feature_dict = dict(zip(img_path,sf.features));len(feature_dict)
# Out:
# 14697

# %%
to_pickle(feature_dict,model_path/'feature_dict.pkl')

# %%
feature_dim = len(next(iter(feature_dict.values())))
t = AnnoyIndex(feature_dim, metric='euclidean')

for i, vector in enumerate(feature_dict.values()):
    t.add_item(i, vector)

# %%
vector.shape
# Out:
# (512,)

# %%
t.build(10) # 10 trees
# Out:
# True

# %%
t.get_n_items()
# Out:
# 14697

# %%
t.save(str(model_path/'test3.ann'))
# Out:
# True

# %% [markdown]
# ##### test

# %%
from IPython.display import Image,display

# %%
similar = t.get_nns_by_vector(sf.features[-1], 1, search_k=-1, include_distances=False)

# %%
# Out:
# [14367]

# %%
label_df = mapping_df[mapping_df['paths'].isin([list(feature_dict.keys())[i] for i in similar])];label_df
# Out:
#                              paths            labels  is_valid
# index
# 25004  d7e10e790aeb740e_4-0114.jpg  ivory,Midcentury     False

# %%
# Out:
# 10607

# %%
Image(ssd_pictures_path/list(feature_dict.keys())[similar[0]])

# %%
for i in similar:
    display(Image(filename =ssd_pictures_path/list(feature_dict.keys())[i], width=500, height=500))

# %%
i
# Out:
# 4025

# %%
for i in similar:
    display(Image(filename =ssd_pictures_path/list(feature_dict.keys())[i], width=500, height=500))
