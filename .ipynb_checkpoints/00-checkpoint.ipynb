# %%
# default_exp learn

# %%
#export 
import pandas as pd
from pymongo import MongoClient
from pathlib import Path
import shutil
from mytools.tools import *
from fur.paths import *
from annoy import AnnoyIndex

from fastai.vision.all import *

import nested_lookup

# %%
#export
def save_file_from_url(url, fname):
    r = requests.get(url, allow_redirects=True)
    open(fname, 'wb').write(r.content)

# %%
def images_df():
    pics_path = ssd_pictures_path
#     pics_path = Path('/home/dima/houzz_parse/PICS')
    mongo_connect = MongoClient('mongodb://localhost:27017')
    mongodb = mongo_connect['houzz']
    cursor =mongodb['FurnitureItem'].find()
    data = list(cursor)
    pics = pd.DataFrame(list(pics_path.ls()),columns=['paths'])
    pics['file_name'] = pics['paths'].apply(lambda x:x.name)
    pics['image'] = pics['file_name'].str.split('_').str[0]
    data_filtered = nested_lookup.nested_delete(data,'url_img_product')
    img_keys = nested_lookup.nested_lookup('url_img_product',data)
    img_keys = [list(item.keys()) for item in img_keys]
    df = pd.json_normalize(data_filtered)
    df.columns = [c.split('.')[1] if len(c.split('.'))>1 else c for c in df.columns ]
    df['image'] = img_keys
    df = df.explode('image')
    df = pics.merge(df,on='image')
    df = df.drop_duplicates('image').reset_index(drop=True)
    df.columns = df.columns.str.lower()
    return df.drop(columns=['file_name','image','_id'])

# %%
#export
def mk_model_dir(learner_name):
    model_name = f'model_{learner_name}_{pd.Timestamp.now()}'
    model_path = models_path/model_name
    if not model_path.is_dir(): model_path.mkdir()
    return model_path

# %%
len(ssd_pictures_path.ls())
# Out:
# 194442

# %%
mapping_df
# Out:
#                                                                      paths  \
# 0       /home/dima/ssd/furniture_data/pictures/f3912f5007322a53_4-2628.jpg
# 1       /home/dima/ssd/furniture_data/pictures/0f119b8e0e139b63_4-1400.jpg
# 2       /home/dima/ssd/furniture_data/pictures/87b177400cfe92cb_4-8234.jpg
# 3       /home/dima/ssd/furniture_data/pictures/6b41a2140f907733_4-3884.jpg
# 4       /home/dima/ssd/furniture_data/pictures/a31138c10c1aa8ed_4-5493.jpg
# ...                                                                    ...
# 191954  /home/dima/ssd/furniture_data/pictures/27a168fc077fa7f8_4-6738.jpg
# 191955  /home/dima/ssd/furniture_data/pictures/7bb12fd10c2e1408_4-4648.jpg
# 191956  /home/dima/ssd/furniture_data/pictures/2911cab60b23e0b6_4-4796.jpg
# 191957  /home/dima/ssd/furniture_data/pictures/0f219e1b0f5fe2e0_4-8511.jpg
# 191958  /home/dima/ssd/furniture_data/pictures/7291989e0ba2192a_4-6090.jpg
#
#                                                                                                                                 url  \
# 0             https://www.houzz.com/products/puerto-counter-height-stool-with-black-frame-purple-weave-black-frame-prvw-vr~54394155
# 1                        https://www.houzz.com/products/novogratz-regal-mid-century-sofa-bed-futon-mustard-yellow-prvw-vr~152724942
# 2                      https://www.houzz.com/products/haugen-reclaimed-wood-traditional-hand-carved-console-table-prvw-vr~144104406
# 3                       https://www.houzz.com/products/gdf-studio-lexi-modern-velvet-barstools-turquoise-set-of-2-prvw-vr~127303765
# 4                                           https://www.houzz.com/products/safavieh-greta-accent-table-steel-teal-prvw-vr~105141239
# ...                                                                                                                             ...
# 191954              https://www.houzz.com/products/flash-furniture-contemporary-black-vinyl-adjustable-h-bar-stool-prvw-vr~59367194
# 191955                                              https://www.houzz.com/products/eva-sofette-mod-velvet-vanilla-prvw-vr~116417485
# 191956                    https://www.houzz.com/products/acme-baudouin-upholstered-queen-bed-weathered-oak-26110q-prvw-vr~156773461
# 191957  https://www.houzz.com/products/harper-reversible-chaise-sleeper-sofa-marigold-velvet-innerspring-mattress-prvw-vr~121156644
# 191958    https://www.houzz.com/products/premium-18-directors-chair-mission-oak-frame-with-royal-blue-color-cover-prvw-vr~128319460
#
#                manufactured by                 sold by  \
# 0                Innit Designs           Innit Designs
# 1                    Novogratz                   Houzz
# 2       Sierra Living Concepts  Sierra Living Concepts
# 3                    GDFStudio               GDFStudio
# 4                     Safavieh                   Houzz
# ...                        ...                     ...
# 191954         Flash Furniture             BisonOffice
# 191955              NyeKoncept                   Houzz
# 191956          Acme Furniture              Emma Mason
# 191957                   Apt2B                   Apt2B
# 191958         American Trails             VirVentures
#
#                                    size/weight  \
# 0               W 25" / D 20" / H 40" / 22 lb.
# 1       W 80.5" / D 33.5" / H 32.5" / 91.5 lb.
# 2               W 47" / D 15" / H 29" / 70 lb.
# 3       W 21.5" / D 17.75" / H 40" / 16.76 lb.
# 4               W 22" / D 22" / H 29" / 10 lb.
# ...                                        ...
# 191954                                     NaN
# 191955  W 55.4" / D 30.75" / H 35.25" / 68 lb.
# 191956         W 88" / D 66" / H 59" / 156 lb.
# 191957         W 86" / D 37" / H 30" / 120 lb.
# 191958  W 24.5" / D 17.25" / H 37.75" / 11 lb.
#
#                                       color  \
# 0                              Purple Weave
# 1                            Mustard Yellow
# 2                                       NaN
# 3                                 Turquoise
# 4                                Steel Teal
# ...                                     ...
# 191954                                Black
# 191955                              Vanilla
# 191956                                  Oak
# 191957                      Marigold Velvet
# 191958  Mission Oak Frame/Royal Blue Canvas
#
#                                                         materials  \
# 0                                                 Steel and Vinyl
# 1                                                            Wood
# 2                                                      Solid Wood
# 3                                                New Velvet, Iron
# 4                                                            Pine
# ...                                                           ...
# 191954                                                        NaN
# 191955                                 Mod Velvet, Solid Ash Wood
# 191956                                                       Wood
# 191957  Solid Wood Frame, Hypoallergenic Fabrics, Foam Cushioning
# 191958                                                    OAK/ASH
#
#        assembly required                       category          style  \
# 0                    NaN  Bar Stools And Counter Stools   Contemporary
# 1                    Yes          Living Room Furniture     Midcentury
# 2                     No                 Console Tables  Mediterranean
# 3                    Yes  Bar Stools And Counter Stools   Contemporary
# 4                    Yes     Side Tables And End Tables    Traditional
# ...                  ...                            ...            ...
# 191954               Yes  Bar Stools And Counter Stools   Contemporary
# 191955               Yes                      Loveseats     Midcentury
# 191956               Yes                     Panel Beds    Traditional
# 191957                No                  Sleeper Sofas   Contemporary
# 191958               Yes      Folding Chairs And Stools   Contemporary
#
#                collection  amount currency commercial-grade  \
# 0       Puerto Bar Stools     475      USD              Yes
# 1                   Regal     534      USD              NaN
# 2                     NaN     899      USD              NaN
# 3                     NaN     182      USD              NaN
# 4                     NaN  186.51      USD              NaN
# ...                   ...     ...      ...              ...
# 191954                NaN   117.6      USD              NaN
# 191955                NaN    1104      USD              NaN
# 191956                NaN   972.5      USD              NaN
# 191957             Harper  2590.8      USD              NaN
# 191958                NaN    83.6      USD              Yes
#
#                          size weight designer
# 0                         NaN    NaN      NaN
# 1                         NaN    NaN      NaN
# 2                         NaN    NaN      NaN
# 3                         NaN    NaN      NaN
# 4                         NaN    NaN      NaN
# ...                       ...    ...      ...
# 191954  W 16" / D 19" / H 44"    NaN      NaN
# 191955                    NaN    NaN      NaN
# 191956                    NaN    NaN      NaN
# 191957                    NaN    NaN      NaN
# 191958                    NaN    NaN      NaN
#
# [191959 rows x 17 columns]

# %%
mapping_df = images_df()

mapping_df = mapping_df[mapping_df['category']=='Sofas'].reset_index(drop=True)
mapping_df = mapping_df[['paths','color','materials','style']]

# %%
len(mapping_df['color'].unique())
# Out:
# 743

# %%
mapping_df['color'] = mapping_df['color'].str.lower()

# %%
mapping_df['color'] = mapping_df['color'].str.split(' ')

# %%
mapping_df = mapping_df.explode('color')

# %%
mapping_df['color'] = mapping_df['color'].str.split('/')

# %%
mapping_df = mapping_df.explode('color')

# %%
pdrows(50)

# %%
color = mapping_df.groupby(['color'])['paths'].count().sort_values(ascending=False)[:50].index

# %%
color = color.drop('light','finish:')

# %%
len(color)
# Out:
# 49

# %%
mapping_df.loc[~mapping_df['color'].isin(color),'color'] = np.nan

# %%
mapping_df = mapping_df.reset_index().sort_values('color',ascending=False).drop_duplicates('index').set_index('index').sort_index()

# %%
len(mapping_df)
# Out:
# 25588

# %%
pdrows(10)

# %%
# mapping_df['Materials'] = mapping_df['Materials'].str.lower()
# mapping_df['Materials'] = mapping_df['Materials'].str.replace('/',',').str.strip()

# %%
# selected_colors = (mapping_df.groupby('Color')['paths'].count().sort_values(ascending=False)[:100]).index
# mapping_df = mapping_df[mapping_df['Color'].isin(selected_colors)]

# %%
# selected_materials = mapping_df.groupby('Materials')['paths'].count().sort_values(ascending=False)[:50].index
# mapping_df = mapping_df[mapping_df['Materials'].isin(selected_materials)]

# %%
mapping_df['labels'] = mapping_df['color']+','+mapping_df['style']#+','+mapping_df['Materials']

# %%
mapping_df = mapping_df[['paths','labels']]

# %%
mapping_df['paths'] = mapping_df['paths'].apply(lambda x:x.name)

# %%
mapping_df = mapping_df.dropna()

# %%
mapping_df.loc[mapping_df.sample(int(len(mapping_df)/5)).index,'is_valid'] = True

# %%
mapping_df['is_valid'] = mapping_df['is_valid'].fillna(False)

# %%
len(mapping_df)
# Out:
# 18489

# %%
drop_labels = set(mapping_df[mapping_df['is_valid']==True]['labels'])^set(mapping_df[mapping_df['is_valid']==False]['labels'])

# %%
mapping_df = mapping_df[~mapping_df['labels'].isin(drop_labels)]

# %%
len(mapping_df['labels'].unique())
# Out:
# 164

# %%
dls = ImageDataLoaders.from_df(mapping_df, path = ssd_pictures_path, 
                               label_col=1, item_tfms=Resize(224), valid_col='is_valid')

# %%
dls.show_batch()

# %% [markdown]
# #### learn

# %%
learn = cnn_learner(dls,resnet34, metrics=error_rate)#, metrics=partial(accuracy_multi, thresh=0.5)

# %%
learn.fine_tune(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.425008</td>
#       <td>2.294852</td>
#       <td>0.544372</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.899447</td>
#       <td>1.403769</td>
#       <td>0.357955</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.223142</td>
#       <td>1.124472</td>
#       <td>0.283820</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### extra train

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=9.120108734350651e-06, lr_steep=1.9054607491852948e-06)

# %%
learn.fit_one_cycle(2, slice(2e-6, 1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.992909</td>
#       <td>1.098902</td>
#       <td>0.277597</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.949530</td>
#       <td>1.090592</td>
#       <td>0.277056</td>
#       <td>00:40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### interpret

# %%
learn.show_results()

# %%
interp = Interpretation.from_learner(learn)
interp.plot_top_losses(9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>predicted</th>
#       <th>probabilities</th>
#       <th>loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>antique brass nailhead; antique oak;Traditional;cigar</td>
#       <td></td>
#       <td>tensor([3.8161e-04, 4.6294e-04, 1.6185e-04, 3.0370e-03, 4.3255e-04, 3.8268e-04,\n        1.2732e-04, 3.7599e-04, 5.1184e-04, 3.7968e-04, 5.7208e-04, 3.9412e-04,\n        3.5426e-04, 3.8454e-04, 4.7745e-04, 3.1837e-04, 3.4522e-01, 3.1198e-04,\n        2.6447e-01, 4.1772e-03, 4.6080e-04, 5.6471e-02, 8.1821e-02, 1.0351e-02,\n        7.5963e-04, 4.6652e-04, 4.0805e-04, 2.8050e-03, 6.0763e-04, 7.2754e-04,\n        2.6303e-04, 2.0724e-03, 2.5375e-04, 5.1687e-04, 8.0271e-04, 6.9320e-04,\n        3.5839e-04, 4.9807e-04, 8.2045e-04, 2.4723e-03, 7.0097e-04, 1.9353e-03,\n        4.8214e-04, 4.9555e-04, 2.1571e-03, 3.1388e-03, 9.7057e-04, 6.8551e-04,\n        3.7655e-04, 1.7286e-03, 7.6505e-03, 3.5961e-04, 1.8453e-04, 8.2451e-04,\n        5.1816e-04, 4.3664e-04, 6.0334e-04, 5.9721e-04, 2.0595e-04, 3.0267e-04,\n        1.0882e-03, 2.4219e-04, 9.3138e-04, 4.6866e-04, 1.5324e-03, 1.8782e-02,\n        5.2785e-04, 3.6438e-04, 3.9149e-04, 2.6992e-04, 4.0404e-04, 4.4355e-04,\n        3.1368e-04, 1.5318e-03, 3.2509e-04, 3.3806e-04, 3.4915e-04, 2.6276e-04,\n        4.9223e-04, 6.7171e-04, 7.4791e-04, 4.7219e-04, 6.2473e-04, 5.1476e-04,\n        5.1949e-04, 6.6002e-04, 3.1538e-03, 4.9173e-04, 1.3409e-03, 1.5945e-03,\n        1.5912e-03, 6.1065e-03, 5.9895e-04, 7.5506e-04, 3.4601e-03, 3.0160e-03,\n        6.4567e-04, 1.4652e-03, 6.6211e-04, 6.6614e-04, 5.2957e-04, 5.1419e-04,\n        1.8836e-03, 4.6631e-04, 5.7420e-04, 2.4155e-04, 1.0466e-01, 5.8353e-04,\n        7.2916e-04, 4.4215e-04, 3.2466e-04, 2.3584e-04, 2.5029e-04, 7.6400e-04,\n        2.3020e-03, 9.1546e-04, 2.3363e-03, 4.8706e-04, 1.6533e-03, 3.1075e-04,\n        2.2196e-04, 6.5603e-04, 9.0032e-04, 5.7077e-04, 1.5336e-03, 5.7456e-04,\n        2.9664e-04, 6.1321e-03, 6.4765e-03, 3.3992e-04, 4.3781e-04, 5.0514e-04,\n        3.2216e-04, 5.0210e-03, 1.0626e-03, 1.3967e-03, 6.1837e-04, 3.3013e-04,\n        4.2266e-04, 2.7676e-04, 4.5373e-04, 1.3407e-03, 6.9438e-03, 4.1241e-04,\n        3.3283e-04, 7.2298e-04, 1.8234e-03, 6.6011e-04, 2.4826e-03, 3.0496e-03,\n        3.7987e-04, 2.0988e-03, 4.5013e-04, 1.2479e-03, 1.7685e-03, 3.5500e-04,\n        3.2389e-03, 2.8535e-03, 1.2067e-03, 1.9655e-04, 3.3255e-04, 9.7398e-04,\n        1.6120e-03, 3.3304e-04, 2.5897e-04, 3.5055e-04, 1.1405e-03, 3.5612e-04,\n        2.2702e-04, 8.2054e-03, 1.0242e-03, 8.7839e-04, 3.6748e-03, 3.9123e-04,\n        3.9356e-03, 6.5578e-04, 7.8034e-04, 5.0801e-04, 7.2975e-04, 7.9652e-04,\n        3.7279e-04, 9.6850e-04, 3.0617e-04, 7.1368e-04, 5.3524e-04, 1.1611e-03,\n        2.5059e-04, 5.5462e-04, 8.3996e-04, 1.6272e-04, 5.8093e-04, 8.2632e-04,\n        5.0953e-04, 1.9387e-03, 4.8581e-04, 3.5891e-04, 2.3754e-04, 5.9631e-04,\n        1.1149e-03, 1.2153e-03, 5.0081e-04, 4.9740e-04, 6.5410e-04, 3.4560e-04,\n        2.4776e-04, 7.4510e-04, 6.1555e-04, 4.3167e-04, 2.8189e-04, 3.1484e-04,\n        2.1750e-04, 1.2930e-02, 1.6533e-04, 8.1092e-04, 4.8133e-03, 7.5588e-04,\n        7.6502e-04, 4.4149e-04, 3.1690e-04, 1.0630e-03, 1.2086e-03, 2.4035e-03,\n        7.6120e-04, 1.8087e-03, 1.3005e-03, 8.5600e-04, 4.6716e-03, 1.8478e-03,\n        3.3813e-04, 5.9033e-04, 4.4122e-04, 4.8906e-04, 2.8721e-04, 1.5130e-03,\n        2.6306e-04, 4.2275e-04, 4.9273e-04, 2.5995e-04, 5.3680e-03, 2.2076e-04,\n        1.2593e-02, 8.9329e-05, 3.6228e-04, 3.3555e-04, 7.8683e-04, 1.1822e-03,\n        1.2337e-03, 2.7548e-04, 3.0231e-03, 1.6655e-03, 3.6554e-03, 6.5977e-04,\n        3.9165e-04, 1.0060e-03, 2.0600e-04, 9.8883e-03, 3.5680e-04, 5.3250e-03,\n        5.4700e-03, 2.3606e-04, 6.4142e-04, 7.6252e-04, 9.4739e-04, 5.0230e-04,\n        6.5970e-04, 2.9293e-04, 9.4330e-04, 3.2730e-04, 1.5736e-04, 4.9092e-03,\n        3.3892e-04, 4.1078e-04, 3.4492e-03, 2.8059e-04, 7.4382e-04, 9.8859e-04,\n        4.8858e-04, 2.1435e-03, 3.3934e-04, 5.9060e-04, 1.1927e-03, 9.4792e-04,\n        2.3782e-03, 2.2300e-04, 3.2857e-04, 3.9106e-04, 4.3335e-03, 4.1735e-04,\n        7.5647e-04, 2.9784e-04, 1.4150e-03, 4.5227e-04, 3.8165e-04, 2.8173e-03,\n        4.9031e-04, 3 ...
#       <td>0.0

# %% [markdown]
# #### save model

# %%
model_path = mk_model_dir('sofas_styles__color_singlelabel_10_11')

# %%
learn.export(model_path/'model.pkl')

# %% [markdown]
# #### load model

# %%
learn = load_learner(model_path)

# %%
learn.dls = dls

# %% [markdown]
# ### annoy

# %%
# export 
# this is a hook (learned about it here: https://forums.fast.ai/t/how-to-find-similar-images-based-on-final-embedding-layer/16903/13)
# hooks are used for saving intermediate computations
class SaveFeatures():
    features=None
    def __init__(self, m): 
        self.hook = m.register_forward_hook(self.hook_fn)
        self.features = None
    def hook_fn(self, module, input, output): 
        out = output.detach().cpu().numpy()
        if isinstance(self.features, type(None)):
            self.features = out
        else:
            self.features = np.row_stack((self.features, out))
    def remove(self): 
        self.hook.remove()

# %%
sf = SaveFeatures(learn.model[1][5])

# %%
_= learn.get_preds(ds_idx=0)

# %%
_= learn.get_preds(ds_idx=1)

# %%
len(sf.features)
# Out:
# 18394

# %%
img_path = [str(x) for x in list(dls.train_ds.items['paths'])+list(dls.valid_ds.items['paths'])]

# %%
len(img_path)
# Out:
# 18394

# %%
feature_dict = dict(zip(img_path,sf.features))

# %%
len(feature_dict)==len(img_path)
# Out:
# True

# %%
model_path
# Out:
# Path('/home/dima/furniture_data/models/model_sofas_styles__color_singlelabel_10_11_2020-11-11 10:31:22.893645')

# %%
to_pickle(feature_dict,model_path/'feature_dict.pkl')

# %%
feature_dim = len(next(iter(feature_dict.values())))
t = AnnoyIndex(feature_dim, metric='euclidean')

for i, vector in enumerate(feature_dict.values()):
    t.add_item(i, vector)

# %%
t.build(100) # 10 trees
# Out:
# True

# %%
t.save(str(model_path/'test1.ann'))
# Out:
# True

# %% [markdown]
# ##### test

# %%
from IPython.display import Image,display

# %%
im = ssd_pictures_path/img_path[-55]

# %%
Image(im)

# %%
learn.predict(im)
# Out:
# ('gray,Transitional',
#  TensorImage(66),
#  TensorImage([2.2566e-05, 1.0456e-03, 5.0078e-04, 6.1189e-04, 1.8185e-04, 3.7819e-03,
#          2.3707e-04, 2.9969e-05, 7.9042e-04, 1.6171e-04, 4.1223e-05, 1.0935e-02,
#          1.9442e-05, 2.0722e-04, 1.9762e-04, 5.3133e-05, 3.8976e-05, 1.5281e-04,
#          7.5090e-05, 1.7141e-04, 2.9751e-05, 3.5052e-04, 6.8163e-04, 2.4741e-04,
#          6.3872e-04, 5.6089e-04, 1.7882e-04, 2.8886e-04, 6.8793e-05, 1.1566e-03,
#          8.6012e-04, 2.9285e-04, 1.1321e-01, 2.8965e-04, 8.0496e-05, 7.1765e-05,
#          1.3734e-05, 1.3206e-04, 4.7099e-04, 5.9334e-05, 1.5123e-05, 6.3633e-05,
#          2.5391e-03, 9.4526e-05, 8.4152e-06, 1.1590e-04, 5.2821e-04, 1.6774e-05,
#          3.8700e-05, 3.9612e-05, 5.0343e-04, 1.3311e-04, 5.2482e-05, 1.6752e-04,
#          4.6049e-06, 1.1208e-04, 1.4857e-05, 2.0295e-04, 4.0897e-05, 8.5420e-04,
#          1.1866e-04, 2.1480e-03, 2.9846e-01, 1.8421e-03, 3.4638e-03, 1.4747e-02,
#          3.9763e-01, 1.9357e-04, 1.3856e-05, 6.3874e-05, 4.9034e-05, 2.6215e-04,
#          2.1644e-02, 5.8370e-03, 6.3547e-04, 4.7401e-03, 2.5508e-02, 6.4631e-05,
#          3.5817e-04, 1.9752e-05, 5.4772e-05, 1.3146e-04, 9.3210e-05, 2.6718e-05,
#          2.2266e-05, 5.3324e-05, 3.7132e-05, 4.4288e-05, 3.4290e-05, 8.6776e-06,
#          7.1198e-05, 9.5150e-04, 2.6832e-05, 1.8515e-05, 2.4350e-05, 2.0513e-04,
#          1.7335e-04, 1.2875e-03, 1.1618e-04, 5.5084e-06, 8.3553e-06, 3.1529e-05,
#          4.7943e-05, 5.4791e-05, 8.2085e-05, 9.7968e-05, 1.3539e-04, 1.4379e-04,
#          7.1643e-04, 7.5045e-05, 3.8873e-05, 7.9761e-05, 1.9317e-04, 2.3868e-05,
#          2.6826e-05, 1.3965e-04, 5.2687e-05, 1.4842e-05, 2.4378e-05, 4.8507e-04,
#          2.2901e-02, 8.2419e-05, 5.2829e-04, 3.0869e-05, 1.1443e-02, 3.6925e-04,
#          7.5167e-05, 1.9296e-03, 4.4267e-03, 1.2007e-04, 2.1110e-04, 1.8595e-04,
#          4.8258e-04, 3.3171e-03, 2.9543e-04, 3.4704e-03, 1.9334e-04, 7.8904e-04,
#          7.1448e-05, 3.1991e-04, 1.9837e-04, 1.1498e-03, 3.6624e-05, 2.9965e-03,
#          9.8797e-06, 7.0806e-03, 1.3353e-03, 8.5420e-04, 5.5054e-04, 3.0346e-03,
#          1.0546e-04, 4.1558e-04, 2.9332e-05, 6.2424e-05, 1.9999e-04, 5.3540e-05,
#          1.7401e-04, 8.7404e-05, 4.0519e-04, 2.9753e-05, 1.5047e-04, 1.0708e-03,
#          2.6157e-04, 3.2167e-04]))

# %%
similar = t.get_nns_by_vector(sf.features[-1], 5, include_distances=False)

# %%
similar
# Out:
# [18339, 18180, 2816, 17671, 10508]

# %%
for i in similar:
    display(Image(filename =ssd_pictures_path/list(feature_dict.keys())[i], width=500, height=500))
